# %%
import json

data = {}
data['students'] = []
data['students'].append({
    'name': 'Journey Cabral',
    'GitHubID': '7613164',
    'NetID': '925008599'
})

with open('identity.txt', 'w') as outfile:
    json.dump(data, outfile)
